# %% [markdown]
# Q1: What is Estimation Statistics? Explain point estimate and interval estimate.

# %% [markdown]
# Estimation statistics is a branch of statistics that deals with estimating population parameters based on sample data. It involves two types of estimates: point estimates and interval estimates.
#
# Point Estimate: A single value used to estimate the population parameter. It is obtained by directly using the sample statistic (e.g., sample mean or sample proportion) as an estimate of the corresponding population parameter.
#
# Interval Estimate: A range of values within which the population parameter is likely to fall with a certain level of confidence. It is obtained by constructing a confidence interval around the point estimate.

# %% [markdown]
# Q2. Write a Python function to estimate the population mean using a sample mean and standard
# deviation.

# %%
def estimate_population_mean(sample_mean, sample_std_dev, sample_size):
    """
    Estimate the population mean using sample mean, sample standard deviation, and sample size.

    Parameters:
        sample_mean (float): Sample mean.
        sample_std_dev (float): Sample standard deviation.
        sample_size (int): Sample size.

    Returns:
        float: Estimated population mean.
    """
    return sample_mean

# %%
Q3: What is Hypothesis testing? Why is it used? State the importance of Hypothesis testing.

# %% [markdown]
#  Hypothesis testing is a statistical method used to make decisions about a population based on a sample of data. It involves formulating a null hypothesis (H0) and an alternative hypothesis (Ha) and testing the null hypothesis against the data to determine if there is enough evidence to reject or fail to reject the null hypothesis.
#
# Importance of Hypothesis Testing:
#
# Provides a systematic way to test claims and make decisions based on data.
# Allows us to draw conclusions about populations using sample data.
# Crucial in scientific research, decision-making, and quality control.

# %% [markdown]
#  Hypothesis: The average weight of male college students is greater than the average weight of female college students.

# %%
Q4. Create a hypothesis that states whether the average weight of male college students is greater than
the average weight of female college students

# %%
import scipy.stats as stats

def two_sample_t_test(sample1, sample2):
    """
    Conduct a two-sample t-test for independent samples.

    Parameters:
        sample1 (array-like): Sample data from population 1.
        sample2 (array-like): Sample data from population 2.

    Returns:
        t_statistic (float): Calculated t-statistic.
        p_value (float): Two-tailed p-value.
    """
    t_statistic, p_value = stats.ttest_ind(sample1, sample2)
    return t_statistic, p_value

# %% [markdown]
# Q5. Write a Python script to conduct a hypothesis test on the difference between two population means,
# given a sample from each population.

# %% [markdown]
# Null Hypothesis (H0): A statement that there is no significant difference or effect. It is often denoted as "no difference" or "no effect."
#
# Alternative Hypothesis (Ha): A statement that contradicts the null hypothesis, proposing that there is a significant difference or effect.
#
# Examples:
#
# H0: The new drug has no effect on blood pressure.
# Ha: The new drug decreases blood pressure.
#
# H0: The average response time is the same for two groups.
# Ha: The average response time differs between two groups.

# %% [markdown]
# Q6: What is a null and alternative hypothesis? Give some examples.

# %% [markdown]
# : P-value is the probability of obtaining a test statistic as extreme as the one observed, assuming that the null hypothesis is true. It is used to assess the strength of the evidence against the null hypothesis.
#
# A small p-value (typically less than the chosen significance level) suggests strong evidence to reject the null hypothesis.
# A large p-value suggests weak evidence to reject the null hypothesis, indicating that the data is consistent with the null hypothesis.

# %% [markdown]
# Q7: Write down the steps involved in hypothesis testing.

# %% [markdown]
# Formulate the null hypothesis (H0) and the alternative hypothesis (Ha).
# Choose a significance level (alpha) to determine the threshold for rejecting the null hypothesis.
# Collect sample data from the population.
# Calculate the test statistic based on the sample data.
# Determine the critical region or p-value to make a decision about the null hypothesis.
# Compare the test statistic with the critical value or p-value.
# Make a decision to either reject or fail to reject the null hypothesis.

# %% [markdown]
# Q8. Define p-value and explain its significance in hypothesis testing.

# %% [markdown]
#  P-value is the probability of obtaining a test statistic as extreme as the one observed, assuming that the null hypothesis is true. It is used to assess the strength of the evidence against the null hypothesis.
#
# A small p-value (typically less than the chosen significance level) suggests strong evidence to reject the null hypothesis.
# A large p-value suggests weak evidence to reject the null hypothesis, indicating that the data is consistent with the null hypothesis.

# %% [markdown]
# Q9. Generate a Student's t-distribution plot using Python's matplotlib library, with the degrees of freedom
# parameter set to 10.

# %%
import numpy as np
import matplotlib.pyplot as plt

df = 10  # Degrees of freedom
x = np.linspace(-4, 4, 1000)
y = stats.t.pdf(x, df)

plt.plot(x, y)
plt.title("Student's t-Distribution (df=10)")
plt.xlabel("x")
plt.ylabel("Probability Density")
plt.grid(True)
plt.show()

# %% [markdown]
# Q10. Write a Python program to calculate the two-sample t-test for independent samples, given two
# random samples of equal size and a null hypothesis that the population means are equal.

# %%
import scipy.stats as stats

def two_sample_t_test(sample1, sample2, null_hypothesis):
    """
    Calculate the two-sample t-test for independent samples.

    Parameters:
        sample1 (array-like): Sample data from population 1.
        sample2 (array-like): Sample data from population 2.
        null_hypothesis (float): Value of the null hypothesis (usually 0 for difference test).

    Returns:
        float: t-statistic
        float: p-value
    """
    t_statistic, p_value = stats.ttest_ind(sample1, sample2)
    return t_statistic, p_value

# %% [markdown]
# Q11: What is Student’s t distribution? When to use the t-Distribution.

# %% [markdown]
#  Student’s t distribution is a probability distribution used for estimating the population mean when the sample size is small (typically n < 30) or when the population standard deviation is unknown.
#
# Use the t-Distribution:
#
# When the sample size is small.
# When the population standard deviation is unknown.
# For hypothesis testing and confidence interval estimation.

# %% [markdown]
# Q12: What is t-statistic? State the formula for t-statistic.

# %% [markdown]
# The t-statistic measures how many standard errors the sample mean is away from the hypothesized population mean. It is calculated as:
#
# t = (sample mean - hypothesized mean) / (sample standard deviation / √sample size)

# %% [markdown]
# Q13. A coffee shop owner wants to estimate the average daily revenue for their shop. They take a random
# sample of 50 days and find the sample mean revenue to be $500 with a standard deviation of $50.
# Estimate the population mean revenue with a 95% confidence interval.

# %%
sample_mean = 500
sample_std_dev = 50
sample_size = 50
confidence_level = 0.95

margin_of_error = stats.t.ppf(1 - (1 - confidence_level) / 2, sample_size - 1) * (sample_std_dev / np.sqrt(sample_size))
lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

print(f"Population mean revenue estimate: {sample_mean}")
print(f"95% Confidence Interval: ({lower_bound}, {upper_bound})")
# Out:
# Population mean revenue estimate: 500
# 95% Confidence Interval: (485.79015724388137, 514.2098427561186)

# %% [markdown]
# Q15. An electronics company produces a certain type of product with a mean weight of 5 pounds and a
# standard deviation of 0.5 pounds. A random sample of 25 products is taken, and the sample mean weight
# is found to be 4.8 pounds. Test the hypothesis that the true mean weight of the products is less than 5
# pounds with a significance level of 0.01.

# %%
sample_mean = 4.8
sample_std_dev = 0.5
sample_size = 25
null_hypothesis = 5
significance_level = 0.01

t_statistic, p_value = stats.ttest_1samp(sample_mean, null_hypothesis)

if p_value < significance_level:
    print("Reject the null hypothesis. The true mean weight of the products is less than 5 pounds.")
else:
    print("Fail to reject the null hypothesis. There is no significant evidence of the mean weight being less than 5 pounds.")
# Out:
# Fail to reject the null hypothesis. There is no significant evidence of the mean weight being less than 5 pounds.
# C:\Users\acer\AppData\Local\Temp\ipykernel_5356\1765593996.py:7: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   t_statistic, p_value = stats.ttest_1samp(sample_mean, null_hypothesis)

# %% [markdown]
# Q13. A coffee shop owner wants to estimate the average daily revenue for their shop. They take a random
# sample of 50 days and find the sample mean revenue to be $500 with a standard deviation of $50.
# Estimate the population mean revenue with a 95% confidence interval.

# %%
sample_mean = 8
sample_std_dev = 3
sample_size = 100
null_hypothesis = 10
significance_level = 0.05

t_statistic, p_value = stats.ttest_1samp(sample_mean, null_hypothesis)

if p_value < significance_level:
    print("Reject the null hypothesis. The new drug decreases blood pressure.")
else:
    print("Fail to reject the null hypothesis. There is no significant evidence of a decrease in blood pressure.")
# Out:
# Fail to reject the null hypothesis. There is no significant evidence of a decrease in blood pressure.
# C:\Users\acer\AppData\Local\Temp\ipykernel_5356\486552059.py:7: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   t_statistic, p_value = stats.ttest_1samp(sample_mean, null_hypothesis)

# %% [markdown]
# Q16. Two groups of students are given different study materials to prepare for a test. The first group (n1 =
# 30) has a mean score of 80 with a standard deviation of 10, and the second group (n2 = 40) has a mean
# score of 75 with a standard deviation of 8. Test the hypothesis that the population means for the two
# groups are equal with a significance level of 0.01.

# %%
sample1_mean = 80
sample1_std_dev = 10
sample1_size = 30

sample2_mean = 75
sample2_std_dev = 8
sample2_size = 40

significance_level = 0.01

t_statistic, p_value = stats.ttest_ind_from_stats(sample1_mean, sample1_std_dev, sample1_size,
                                                 sample2_mean, sample2_std_dev, sample2_size)

if p_value < significance_level:
    print("Reject the null hypothesis. The population means for the two groups are different.")
else:
    print("Fail to reject the null hypothesis. There is no significant evidence of a difference in population means.")
# Out:
# Fail to reject the null hypothesis. There is no significant evidence of a difference in population means.

# %% [markdown]
# Q17. A marketing company wants to estimate the average number of ads watched by viewers during a TV
# program. They take a random sample of 50 viewers and find that the sample mean is 4 with a standard
# deviation of 1.5. Estimate the population mean with a 99% confidence interval.

# %%
sample_mean = 4
sample_std_dev = 1.5
sample_size = 50
confidence_level = 0.99

margin_of_error = stats.t.ppf(1 - (1 - confidence_level) / 2, sample_size - 1) * (sample_std_dev / np.sqrt(sample_size))
lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

print(f"Estimated population mean: {sample_mean}")
print(f"99% Confidence Interval: ({lower_bound}, {upper_bound})")
# Out:
# Estimated population mean: 4
# 99% Confidence Interval: (3.4314963358572577, 4.568503664142742)
